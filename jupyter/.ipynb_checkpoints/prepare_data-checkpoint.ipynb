# %%
import os
#import cv2
import matplotlib.pyplot as plt
import numpy as np
import tensorflow

# %%
IMG_SIZE=150
BATCH_SIZE=128

TRAIN_DATA="../dogscats/train/"
VALIDATION_DATA="../dogscats/valid/"

def plot_sample(data):
    class_names = data.class_names
    plt.figure(figsize=(20, 20))
    for images, labels in data.take(1):
        for i in range(20):
            ax = plt.subplot(10, 10, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[labels[i]])
            plt.axis("off")

def plot_single_image(data, index):     
    class_names = data.class_names
    for images, labels in data.take(1):
        plt.imshow(images[index].numpy().astype("uint8"))
        plt.title(class_names[labels[index]])

# %%
train_data=tensorflow.keras.utils.image_dataset_from_directory(
    TRAIN_DATA,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE
)
print(train_data.class_names)
# Out:
# Found 23000 files belonging to 2 classes.
# Using 18400 files for training.
# ['cats', 'dogs']

# %%
validation_data=tensorflow.keras.utils.image_dataset_from_directory(
    VALIDATION_DATA,
    validation_split=None,
    seed=123,
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE
)
print(validation_data.class_names)
# Out:
# Found 2000 files belonging to 2 classes.
# ['cats', 'dogs']

# %%
for image_batch, labels_batch in train_data:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (128, 150, 150, 3)
# (128,)

# %%
for image_batch, labels_batch in validation_data:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (128, 150, 150, 3)
# (128,)

# %%
plot_sample(train_data)

# %%
plot_sample(validation_data)

# %%
plot_single_image(train_data, 32)

# %%
train_data
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
import tempfile
  
train_data.save("./saved_data/train_data/")
validation_data.save("./saved_data/validation_data/")

# %%
new_dataset = tensorflow.data.Dataset.load("./saved_data/train_data/")

# %%
tt=new_dataset.batch(BATCH_SIZE)
plot_single_image(tt, 0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-dedc0bedc234> in <module>
#       1 tt=new_dataset.batch(BATCH_SIZE)
# ----> 2 plot_single_image(tt, 0)
#
# <ipython-input-21-832dd65a24e3> in plot_single_image(data, index)
#      16
#      17 def plot_single_image(data, index):
# ---> 18     class_names = data.class_names
#      19     for images, labels in data.take(1):
#      20         plt.imshow(images[index].numpy().astype("uint8"))
#
# AttributeError: 'BatchDataset' object has no attribute 'class_names'
